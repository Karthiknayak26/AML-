# %%
import datetime as dt
import time as tm
from datetime import datetime
from datetime import time

# %%
tm.time()
# Out:
# 1785834174.4445202

# %%
dt.datetime.now()
# Out:
# datetime.datetime(2026, 8, 4, 9, 3, 32, 982097)

# %%
today=datetime.today()
print("Today's date is:", today)
# Out:
# Today's date is: 2026-08-04 09:06:04.437984

# %%
dtnow=dt.datetime.fromtimestamp(tm.time())
print("Today's date is:", dtnow)
# Out:
# Today's date is: 2026-08-04 09:06:53.686995

# %%
dalta=dt.timedelta(days=100)

# %%
today=dt.date.today()

# %%
print(today-dalta)
# Out:
# 2026-04-26
