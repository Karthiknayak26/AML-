# %%
print("hi")
# Out:
# hi

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd
data = pd.read_csv(r"/home/msis/Desktop/aml_karthik/data_preprocessing/data/Data.csv")
dataset = data

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
y = dataset.iloc[:, 3].values

# %%
# prepare features and target
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, 3].values
# Out:
# array([[4.40000000e+01, 7.20000000e+04],
#        [2.70000000e+01, 4.80000000e+04],
#        [3.00000000e+01, 5.40000000e+04],
#        [3.80000000e+01, 6.10000000e+04],
#        [4.00000000e+01, 6.37777778e+04],
#        [3.50000000e+01, 5.80000000e+04],
#        [3.87777778e+01, 5.20000000e+04],
#        [4.80000000e+01, 7.90000000e+04],
#        [5.00000000e+01, 8.30000000e+04],
#        [3.70000000e+01, 6.70000000e+04]])

# %%
# handle missing values and encode categorical features
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

numeric_features = ['Age', 'Salary']
categorical_features = ['Country']

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean'))
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

x = preprocessor.fit_transform(X)
x
# Out:
# [[7.00000000e+00 7.20000000e+04]
#  [0.00000000e+00 4.80000000e+04]
#  [1.00000000e+00 5.40000000e+04]
#  [4.00000000e+00 6.10000000e+04]
#  [6.00000000e+00 6.37777778e+04]
#  [2.00000000e+00 5.80000000e+04]
#  [5.00000000e+00 5.20000000e+04]
#  [8.00000000e+00 7.90000000e+04]
#  [9.00000000e+00 8.30000000e+04]
#  [3.00000000e+00 6.70000000e+04]]

# %%
# final feature matrix
x.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 from sklearn.compose import ColumnTransformer
#       2 ct=ColumnTransformer([("country",OneHotEncoder(),[0])],remainder="passthrough")
# ----> 3 x=ct.fit_transform(x)
#       4 x.astype(int)
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/compose/_column_transformer.py:979, in ColumnTransformer.fit_transform(self, X, y, **params)
#     976 else:
#     977     routed_params = self._get_empty_routing()
# --> 979 result = self._call_func_on_transformers(
#     980     X,
#     981     y,
#     982     _fit_transform_one,
#     983     column_as_labels=False,
#     984     routed_params=routed_params,
#     985 )
#     987 if not result:
#     988     self._update_fitted_transformers([])
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/compose/_column_transformer.py:889, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     877             extra_args = {}
#     878         jobs.append(
#     879             delayed(func)(
#     880                 transformer=clone(trans) if not fitted else trans,
#    (...)    886             )
#     887         )
# --> 889     return Parallel(n_jobs=self.n_jobs)(jobs)
#     891 except ValueError as e:
#     892     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/pipeline.py:1566, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1564 with _print_elapsed_time(message_clsname, message):
#    1565     if hasattr(transformer, "fit_transform"):
# -> 1566         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1567     else:
#    1568         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1569             X, **params.get("transform", {})
#    1570         )
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/base.py:969, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     954         warnings.warn(
#     955             (
#     956                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    964             UserWarning,
#     965         )
#     967 if y is None:
#     968     # fit method of arity 1 (unsupervised transformation)
# --> 969     return self.fit(X, **fit_params).transform(X)
#     970 else:
#     971     # fit method of arity 2 (supervised transformation)
#     972     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/preprocessing/_encoders.py:1000, in OneHotEncoder.fit(self, X, y)
#     981 @_fit_context(prefer_skip_nested_validation=True)
#     982 def fit(self, X, y=None):
#     983     """
#     984     Fit OneHotEncoder to X.
#     985
#    (...)    998         Fitted encoder.
#     999     """
# -> 1000     self._fit(
#    1001         X,
#    1002         handle_unknown=self.handle_unknown,
#    1003         ensure_all_finite="allow-nan",
#    1004     )
#    1005     self._set_drop_idx()
#    1006     self._n_features_outs = self._compute_n_features_outs()
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/preprocessing/_encoders.py:87, in _BaseEncoder._fit(self, X, handle_unknown, ensure_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#      85 self._check_infrequent_enabled()
#      86 validate_data(self, X=X, reset=True, skip_check_array=True)
# ---> 87 X_list, n_samples, n_features = self._check_X(
#      88     X, ensure_all_finite=ensure_all_finite
#      89 )
#      90 self.n_features_in_ = n_features
#      92 if self.categories != "auto":
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/preprocessing/_encoders.py:54, in _BaseEncoder._check_X(self, X, ensure_all_finite)
#      41 """
#      42 Perform custom check_array:
#      43 - convert list of strings to object dtype
#    (...)     50
#      51 """
#      52 if not (hasattr(X, "iloc") and getattr(X, "ndim", 0) == 2):
#      53     # if not a dataframe, do normal check_array validation
# ---> 54     X_temp = check_array(X, dtype=None, ensure_all_finite=ensure_all_finite)
#      55     if not hasattr(X, "dtype") and np.issubdtype(X_temp.dtype, np.str_):
#      56         X = check_array(X, dtype=object, ensure_all_finite=ensure_all_finite)
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:994, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     992 if sp.issparse(array):
#     993     _ensure_no_complex_data(array)
# --> 994     array = _ensure_sparse_format(
#     995         array,
#     996         accept_sparse=accept_sparse,
#     997         dtype=dtype,
#     998         copy=copy,
#     999         ensure_all_finite=ensure_all_finite,
#    1000         accept_large_sparse=accept_large_sparse,
#    1001         estimator_name=estimator_name,
#    1002         input_name=input_name,
#    1003     )
#    1004     if ensure_2d and array.ndim < 2:
#    1005         raise ValueError(
#    1006             f"Expected 2D input, got input with shape {array.shape}.\n"
#    1007             "Reshape your data either using array.reshape(-1, 1) if "
#    1008             "your data has a single feature or array.reshape(1, -1) "
#    1009             "if it contains a single sample."
#    1010         )
#
# File ~/Desktop/aml_karthik/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:600, in _ensure_sparse_format(sparse_container, accept_sparse, dtype, copy, ensure_all_finite, accept_large_sparse, estimator_name, input_name)
#     598 if accept_sparse is False:
#     599     padded_input = " for " + input_name if input_name else ""
# --> 600     raise TypeError(
#     601         f"Sparse data was passed{padded_input}, but dense data is required. "
#     602         "Use '.toarray()' to convert to a dense numpy array."
#     603     )
#     604 elif isinstance(accept_sparse, (list, tuple)):
#     605     if len(accept_sparse) == 0:
#
# TypeError: Sparse data was passed, but dense data is required. Use '.toarray()' to convert to a dense numpy array.
