# %%
import numpy as np

# %%
#operation
x=np.array([1,2,3])
y=np.array([4,5,6])
print(x)
print(y)
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x**2)
# Out:
# [1 2 3]
# [4 5 6]
# [5 7 9]
# [-3 -3 -3]
# [ 4 10 18]
# [0.25 0.4  0.5 ]
# [1 4 9]

# %%
x.dot(y)
# Out:
# np.int64(32)

# %%
z=np.array([y,y**2])
z
# Out:
# array([[ 4,  5,  6],
#        [16, 25, 36]])

# %%
z.shape
# Out:
# (2, 3)

# %%
z.T
# Out:
# array([[ 4, 16],
#        [ 5, 25],
#        [ 6, 36]])

# %%
len(z)
# Out:
# 2

# %%
z.T.shape
# Out:
# (3, 2)

# %%
z.dtype
# Out:
# dtype('int64')

# %%
z=z.astype('f')
z.dtype
# Out:
# dtype('float32')

# %%
a=np.array([1,3,5])
a.sum()
# Out:
# np.int64(9)

# %%
a.max()
# Out:
# np.int64(5)

# %%
a.min()
# Out:
# np.int64(1)

# %%
a.mean()
# Out:
# np.float64(3.0)

# %%
a.std()
# Out:
# np.float64(1.632993161855452)

# %%
a.argmin()

# %%
import numpy as np
s=np.arange(100)
s
