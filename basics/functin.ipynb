# %%
def calculatesquare(num):
    return num*num

# %%
numbers=(1,2,3,4,5)
resut=map(calculatesquare,numbers)
print(resut)

# %%
for i in numbers:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
numbers=(1,2,3,4,7)
result=map(lambda num:num*num,numbers)
print(result)

# %%
for i in numbers:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 7

# %%
num1=[4,5,6]
num2=[7,8,9]
result=map(lambda x,y:x+y,num1,num2)
print(result)
list(result)
# Out:
# ...
# [11, 13, 15]

# %%
for i in result:
    print(i)
# Out:
# 11
# 13
# 15

# %%
people={'python programing','computer lab','student scored a grade A'}
def split_title_and_name(person):
    title =person.split()[0]
    last_name=person.split()[-1]
    return '{} {}'.format(title,last_name)
list(map(split_title_and_name,people))
# Out:
# ['python programing', 'computer lab', 'student A']

# %%
#write code using lambda function that takes in threee patameteras and adds the first two 
#write your own program to show the use if lambda function

# %%
#program to double each item in a list using map()

# %%
#the python programming language:lambda and list comprehension s
#hers is a example of lambda that takes
